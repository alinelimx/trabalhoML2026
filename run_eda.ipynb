# %%
from dados.carregamento import carregar_dados
from EDA.estatisticas import calcular_estatisticas
from EDA.graficos import (
    plotar_histograma,
    plotar_boxplots,
    plotar_coeficiente_variacao,
    plotar_correlacao,
    plotar_serie_temporal,
)

df, colunas_meses = carregar_dados()

estatisticas = calcular_estatisticas(df, colunas_meses)

plotar_histograma(df)
plotar_boxplots(df, estatisticas)
plotar_coeficiente_variacao(estatisticas)
plotar_correlacao(df, estatisticas, colunas_meses)
plotar_serie_temporal(df, colunas_meses)
# Out:
# Salvo: EDA\estatistica_descritiva_por_classificacao.csv
